# %% [markdown]
# *Set environment and download the data for computation
#
# Main steps:
#
# Make a directory somewhere in your google drive
#
# Copy files there
#
# Mount  google drive so colab can see those files and directories
#
# run the train and so on...
#
# Quite few indeed
#
# *

# %% [markdown]
# Mount google drive , this will promt instructions and passwd and so on...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ls

# %%
# change dir for what you used, next one is from my setup
root_path = 'gdrive/My Drive/RL/RLDQTrading'
# %cd $root_path

# %%
# !ls
# Out:
# agent	      info		      PlotModel.py    README.md
# constant.py   LICENSE		      PVQEvaluate.py  RLDataExample.ipynb
# data	      MLWriteRLTrainData.PNG  PVQTrain.py     RLDataExample.md
# functions.py  models		      __pycache__

# %%
import PVQTrain
stock_name = "RLDataForCL60D"

# %%
PVQTrain.main(stock_name, 10, 4) # change parameters ....
# Out:
# func Datashape:  (1751, 8)
# func Features shape:  (1748, 4, 6) (1748,)
# DataLength:  1747
# Features:  6
# Timesteps to use:  4
# Episode 0/10
# Total Profit (Points) : 2.5300
# Training left:  1.27 minutes
# --------------------------------
# Episode 1/10
# Total Profit (Points) : -5.6300
# Training left:  0.98 minutes
# --------------------------------
# Episode 2/10
# Total Profit (Points) : -2.9600
# Training left:  0.77 minutes
# --------------------------------
# Episode 3/10
# Total Profit (Points) : -2.1100
# Training left:  0.63 minutes
# --------------------------------
# Episode 4/10
# Total Profit (Points) : -12.3500
# Training left:  0.52 minutes
# --------------------------------
# Episode 5/10
# Total Profit (Points) : 16.9600
# Training left:  0.40 minutes
# --------------------------------
# Episode 6/10
# Total Profit (Points) : 7.8700
# Training left:  0.30 minutes
# --------------------------------
# Episode 7/10
# Total Profit (Points) : -1.7600
# ...
