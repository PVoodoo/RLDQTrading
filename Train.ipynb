# %% [markdown]
# # **No MORE reasonable to run at colab, run at your own local machine, much faster, no need for GPU/TPU !!**
# (or connect to your local runtime..)

# %% [markdown]
# *Set environment and download the data for computation
#
# Main steps:
#
# Make a directory somewhere in your google drive
#
# Copy files there
#
# Mount  google drive so colab can see those files and directories
#
# run the train and so on...
#
# Quite few indeed
#
# *

# %% [markdown]
# Mount google drive , this will promt instructions and authorization code and so on...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# change dir for what you used, next one is from my setup
root_path = 'gdrive/My Drive/RL/RLDQTrading'
# %cd $root_path
# Out:
# /content/gdrive/My Drive/RL/RLDQTrading

# %%
# !ls
# Out:
# agent	      info		      PlotModel.py    README.md
# constant.py   LICENSE		      PVQEvaluate.py  RLDataExample.ipynb
# data	      MLWriteRLTrainData.PNG  PVQTrain.py     RLDataExample.md
# functions.py  models		      __pycache__     Train.ipynb

# %%
import PVQTrain

# %%
stock_name = "RLDataFor18YM60D"
PVQTrain.main(stock_name, 10000, 4) # change parameters ....
# Out:
# func Datashape:  (8934, 8)
# func Features shape:  (8931, 4, 6) (8931,)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# DataLength:  8930
# Features:  6
# Timesteps to use:  4
# Episode 0/10000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Total Profit (Points) : -653.0000
# Training left:  496.14 hours
# --------------------------------
# Episode 1/10000
# Total Profit (Points) : 628.0000
# Training left:  525.46 hours
# --------------------------------
# Episode 2/10000
# Total Profit (Points) : 18.0000
# ...
